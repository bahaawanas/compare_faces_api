# %%
# !pip install mtcnn
# !pip install keras_facenet
import cv2
from mtcnn import MTCNN
from keras_facenet import FaceNet
from scipy.spatial.distance import cosine
import matplotlib.pyplot as plt
# Out:
# Collecting mtcnn
#   Using cached mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: keras>=2.0.0 in c:\users\zaghloula\anaconda3\lib\site-packages (from mtcnn) (2.14.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\zaghloula\anaconda3\lib\site-packages (from mtcnn) (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\zaghloula\anaconda3\lib\site-packages (from opencv-python>=4.1.0->mtcnn) (1.26.4)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1
# Collecting keras_facenet
#   Using cached keras-facenet-0.3.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: mtcnn in c:\users\zaghloula\anaconda3\lib\site-packages (from keras_facenet) (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in c:\users\zaghloula\anaconda3\lib\site-packages (from mtcnn->keras_facenet) (2.14.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\zaghloula\anaconda3\lib\site-packages (from mtcnn->keras_facenet) (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\zaghloula\anaconda3\lib\site-packages (from opencv-python>=4.1.0->mtcnn->keras_facenet) (1.26.4)
# Building wheels for collected packages: keras_facenet
#   Building wheel for keras_facenet (setup.py): started
#   Building wheel for keras_facenet (setup.py): finished with status 'done'
#   Created wheel for keras_facenet: filename=keras_facenet-0.3.2-py3-none-any.whl size=10387 sha256=ca2a3ab2bf2aa07ccb31dabdb616333ab1a5a93a8a938da78f2c099fb5d8b213
#   Stored in directory: c:\users\zaghloula\appdata\local\pip\cache\wheels\b4\70\d0\0f19dd7e718b546b908ff9027dbd752b0686eb2fa32333e084
# Successfully built keras_facenet
# Installing collected packages: keras_facenet
# Successfully installed keras_facenet-0.3.2

# %%
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image_rgb

# %%
def detect_and_align_face(image_rgb):
    detector = MTCNN()
    # Detect faces
    results = detector.detect_faces(image_rgb)
    if results:
        # Get the bounding box of the first face
        x, y, width, height = results[0]['box']
        # Crop the face region with a margin
        margin = 0.2  # Adjust margin as needed
        x_min, y_min = max(x - int(margin * width), 0), max(y - int(margin * height), 0)
        x_max, y_max = min(x + width + int(margin * width), image_rgb.shape[1]), min(y + height + int(margin * height), image_rgb.shape[0])
        # Crop the face with margin
        face = image_rgb[y_min:y_max, x_min:x_max]
        # Resize the face to a standard size (160x160)
        aligned_face = cv2.resize(face, (160, 160))
        return aligned_face
    else:
        return None

# %%
def get_face_embedding(face):
    embedder = FaceNet()
    # Get the face embedding
    embedding = embedder.embeddings([face])[0]
    return embedding

# %%
def is_same_person(embedding1, embedding2, threshold=0.5):
    # Calculate the cosine distance between embeddings
    distance = cosine(embedding1, embedding2)
    # Check if the distance is below the threshold
    return distance < threshold

# %%
def compare_faces(image_path1, image_path2):
    # Preprocess both images
    image1_rgb = preprocess_image(image_path1)
    image2_rgb = preprocess_image(image_path2)

    # Detect and align faces
    face1 = detect_and_align_face(image1_rgb)
    face2 = detect_and_align_face(image2_rgb)

    if face1 is not None and face2 is not None:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(face1)
        plt.title('Face 1')
        plt.axis('off')

        plt.subplot(1, 2, 2)
        plt.imshow(face2)
        plt.title('Face 2')
        plt.axis('off')
        plt.show()
        # Get embeddings for the faces
        embedding1 = get_face_embedding(face1)
        embedding2 = get_face_embedding(face2)
        # Compare the embeddings
        return is_same_person(embedding1, embedding2)
    else:
        return False

# %%
image_path_id = 'amr_id.jpg'
image_path_selfie = 'amr4.jpg'

# %%
result = compare_faces(image_path_id, image_path_selfie)
# Print the result
print(f"Is the person the same? {'Yes' if result else 'No'}")
# Out:
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 130ms/step
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001EF299F7370> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 5/5 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 2s 2s/step
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001EF35FFD120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# Is the person the same? Yes
